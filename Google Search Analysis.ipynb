# %% [markdown]
# # Google Search Analysis

# %% [markdown]
# Installing pytrends

# %%
# !pip install pytrends

# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %% [markdown]
# Taking the keyword from the user, analyzing Google search trends, and then creating a data frame with the top 10 countries

# %%
word = input(print("Enter keyword"))
trends.build_payload(kw_list = [word])
data = trends.interest_by_region()
data = data.sort_values(by=word, ascending=False)
data = data.head(10)
print(data)
# Out:
#  Enter keyword
# NoneBrooklyn Nine Nine
#                       Brooklyn Nine Nine
# geoName
# Iceland                              100
# Australia                             91
# New Zealand                           68
# Ireland                               60
# Singapore                             58
# Canada                                58
# Philippines                           32
# Denmark                               27
# United Arab Emirates                  27
# Cyprus                                26

# %% [markdown]
# Visualizing results using a bar chart

# %%
data.reset_index().plot(x="geoName", y=word, 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# Google search trend over the years

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=[word])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data[word].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
